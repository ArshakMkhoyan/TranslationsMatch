# %%
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

from tensorflow.keras import layers, Sequential
from tensorflow import keras
import tensorflow as tf

from glob import glob
import pandas as pd
import numpy as np
import os

pd.options.display.max_colwidth = 100

# %%
os.chdir("/content/drive/MyDrive/SKBKonturTest")

# %% [markdown]
# ## Train Model

# %%
def init_model(input_shape):
  model = keras.Sequential(
      [
          layers.Dense(128, input_shape=input_shape , activation="relu", name="Layer1"),
          layers.Dense(32, activation="relu", name="Layer2"),
          layers.Dense(1, activation='sigmoid' ,name="SigmoidLayer"),
      ]
  )

  model.compile(
      optimizer=keras.optimizers.Adam(),
      loss=keras.losses.BinaryCrossentropy(),
      metrics=[keras.metrics.BinaryAccuracy(), keras.metrics.Precision(), keras.metrics.Recall()],
  )
  return model

def get_model_and_parameters(models_train_dir, best_model_dir, patience):
  n_epochs_trained = len(os.listdir(models_train_dir))

  if n_epochs_trained == 0:
    model = init_model(input_shape=(1536,))
    fscore_prev = 0
    print('Initialized new model.')
  else:
    last_model_path = glob(f'{models_dir}/model_epoch-{n_epochs_trained}*')[0]
    
    # Update patience
    best_model = glob(f'{best_model_dir}/model_epoch-*')[0]
    best_epoch = int(best_model.split('model_epoch-')[1].split('_valfscore-')[0])
    patience = patience - (n_epochs_trained - best_epoch)
    print(f'Patience: {patience}')

    # Update fscore_prev
    fscore_prev = float(best_model.split('valfscore-')[1].split('.h5')[0])
    print(f'Best F1 Score: {fscore_prev}')

    # Load model
    model = keras.models.load_model(last_model_path)
    print(f"Loaded model: {last_model_path}")

    return model, fscore_prev, patience

def train_iter(model, fscore_prev, patience, n_iter):
  train_X = np.load(f'processed_data/train/X_processed_{n_iter}.npy')
  train_y = np.load(f'processed_data/train/y_processed_{n_iter}.npy')

  model.fit(x=train_X,
            y=train_y,
            batch_size=batch_size,
            epochs=1,
            verbose=1
            )
  
  del train_X, train_y
    
  return model, fscore_prev, patience

def train_epoch(model, fscore_prev, patience):
  for n_iter in range(n_processed):
    model, fscore_prev, patience = train_iter(model, fscore_prev, patience, n_iter)
    
  return model, fscore_prev, patience

# %%
batch_size = 1024
epochs = 30

# %%
model, fscore_prev, patience = get_model_and_parameters(models_train_dir='trained_models/sample_train',
                                                        best_model_dir='best_models/sample_train', patience=5)
# Out:
# Patience: 4
# Best F1 Score: 0.9217171358333452
# Loaded model: trained_models/model_epoch-10_valfscore-0.9213.h5

# %%
val_X = np.load('processed_data/val/X_processed_0.npy')
val_y = np.load('processed_data/val/y_processed_0.npy')

# %%
n_processed = len(os.listdir('processed_data/train')) // 2
n_epochs_trained = len(os.listdir('trained_models/sample_train'))

for epoch in range(n_epochs_trained, epochs):
  print(f'Epoch: {epoch}')

  model, fscore_prev, patience = train_epoch(model, fscore_prev, patience)

  pred_y = model.predict(val_X) > 0.5

  precision, recall, fscore, _ = precision_recall_fscore_support(val_y, pred_y, average='binary')
  accuracy = accuracy_score(val_y, pred_y)
  print(f"val_accuracy: {accuracy}, val_precision: {precision}, val_recall: {recall}, val_fscore: {fscore}")

  if fscore > fscore_prev:
    patience = 5
    fscore_prev = fscore
    os.remove(glob('best_models/sample_train/model_epoch*')[0])
    model.save(f'best_models/sample_train/model_epoch-{epoch + 1}_valfscore-{fscore:.4f}.h5')
  else:
    patience -= 1

  model.save(f'trained_models/sample_train/model_epoch-{epoch + 1}_valfscore-{fscore:.4f}.h5')
  if patience == 0:
    print('Training stoped by early stopping')
    break
  print('-' * 40)
# Out:
# Epoch: 10
# 293/293 [==============================] - 2s 5ms/step - loss: 0.0197 - binary_accuracy: 0.9950 - precision: 0.9753 - recall: 0.9122
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0194 - binary_accuracy: 0.9950 - precision: 0.9747 - recall: 0.9167
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0198 - binary_accuracy: 0.9949 - precision: 0.9723 - recall: 0.9147
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0193 - binary_accuracy: 0.9951 - precision: 0.9763 - recall: 0.9167
# 293/293 [==============================] - 2s 7ms/step - loss: 0.0192 - binary_accuracy: 0.9948 - precision: 0.9710 - recall: 0.9146
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0189 - binary_accuracy: 0.9952 - precision: 0.9765 - recall: 0.9167
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0192 - binary_accuracy: 0.9951 - precision: 0.9751 - recall: 0.9144
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0192 - binary_accuracy: 0.9950 - precision: 0.9760 - recall: 0.9122
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0202 - binary_accuracy: 0.9948 - precision: 0.9735 - recall: 0.9121
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0206 - binary_accuracy: 0.9947 - precision: 0.9739 - recall: 0.9086
# 183/183 [==============================] - 1s 6ms/step - loss: 0.0186 - binary_accuracy: 0.9952 - precision: 0.9765 - recall: 0.9186
# val_accuracy: 0.9926039458175012, val_precision: 0.9333145036011863, val_recall: 0.9034586466165414, val_fscore: 0.9181439288691303
# ----------------------------------------
# Epoch: 11
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0193 - binary_accuracy: 0.9949 - precision: 0.9748 - recall: 0.9117
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0189 - binary_accuracy: 0.9953 - precision: 0.9774 - recall: 0.9201
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0195 - binary_accuracy: 0.9950 - precision: 0.9735 - recall: 0.9150
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0189 - binary_accuracy: 0.9953 - precision: 0.9771 - recall: 0.9193
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0184 - binary_accuracy: 0.9952 - precision: 0.9749 - recall: 0.9188
# 293/293 [==============================] - 2s 7ms/step - loss: 0.0185 - binary_accuracy: 0.9952 - precision: 0.9754 - recall: 0.9190
# 293/293 [==============================] - 2s 8ms/step - loss: 0.0189 - binary_accuracy: 0.9951 - precision: 0.9743 - recall: 0.9152
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0187 - binary_accuracy: 0.9951 - precision: 0.9746 - recall: 0.9164
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0197 - binary_accuracy: 0.9950 - precision: 0.9759 - recall: 0.9145
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0200 - binary_accuracy: 0.9949 - precision: 0.9746 - recall: 0.9116
# 183/183 [==============================] - 1s 6ms/step - loss: 0.0181 - binary_accuracy: 0.9952 - precision: 0.9776 - recall: 0.9194
# val_accuracy: 0.9929340819766996, val_precision: 0.9538068981698733, val_recall: 0.8891592617908407, val_fscore: 0.9203492238683476
# ----------------------------------------
# Epoch: 12
# 293/293 [==============================] - 2s 8ms/step - loss: 0.0185 - binary_accuracy: 0.9952 - precision: 0.9749 - recall: 0.9170
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0186 - binary_accuracy: 0.9952 - precision: 0.9764 - recall: 0.9193
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0189 - binary_accuracy: 0.9952 - precision: 0.9760 - recall: 0.9180
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0184 - binary_accuracy: 0.9954 - precision: 0.9775 - recall: 0.9215
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0182 - binary_accuracy: 0.9951 - precision: 0.9746 - recall: 0.9183
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0180 - binary_accuracy: 0.9954 - precision: 0.9779 - recall: 0.9207
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0186 - binary_accuracy: 0.9951 - precision: 0.9745 - recall: 0.9163
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0183 - binary_accuracy: 0.9952 - precision: 0.9756 - recall: 0.9173
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0192 - binary_accuracy: 0.9951 - precision: 0.9769 - recall: 0.9150
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0195 - binary_accuracy: 0.9950 - precision: 0.9748 - recall: 0.9137
# 183/183 [==============================] - 1s 6ms/step - loss: 0.0179 - binary_accuracy: 0.9953 - precision: 0.9782 - recall: 0.9204
# val_accuracy: 0.9930269719986795, val_precision: 0.9592561885585692, val_recall: 0.8857416267942584, val_fscore: 0.9210343013916726
# ----------------------------------------
# Epoch: 13
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0180 - binary_accuracy: 0.9953 - precision: 0.9776 - recall: 0.9182
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0181 - binary_accuracy: 0.9954 - precision: 0.9776 - recall: 0.9224
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0183 - binary_accuracy: 0.9953 - precision: 0.9751 - recall: 0.9206
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0184 - binary_accuracy: 0.9952 - precision: 0.9752 - recall: 0.9205
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0181 - binary_accuracy: 0.9952 - precision: 0.9739 - recall: 0.9202
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0175 - binary_accuracy: 0.9957 - precision: 0.9794 - recall: 0.9247
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0181 - binary_accuracy: 0.9954 - precision: 0.9767 - recall: 0.9200
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0180 - binary_accuracy: 0.9954 - precision: 0.9778 - recall: 0.9195
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0189 - binary_accuracy: 0.9952 - precision: 0.9772 - recall: 0.9176
# 293/293 [==============================] - 2s 6ms/step - loss: 0.0191 - binary_accuracy: 0.9951 - precision: 0.9771 - recall: 0.9145
# 183/183 [==============================] - 1s 6ms/step - loss: 0.0176 - binary_accuracy: 0.9953 - precision: 0.9773 - recall: 0.9206
# val_accuracy: 0.9925323953951655, val_precision: 0.9311820690431942, val_recall: 0.9041695146958305, val_fscore: 0.9174770075878428
# Training stoped by early stopping

# %% [markdown]
# ## Check wrong predictions

# %%
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('Data/train_data.tsv', sep='\t', index_col=0)
train_data, valid_data = train_test_split(train, test_size=0.2, stratify=train['answer'], random_state=42, shuffle=True)

val_X = np.load('processed_data/val/X_processed_0.npy')
val_y = np.load('processed_data/val/y_processed_0.npy')
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
model = keras.models.load_model(glob('best_model/model_*.h5')[0])

# %%
pred_y = model.predict(val_X) > 0.5

# %%
valid_data[pred_y.reshape(-1) != val_y.reshape(-1)].head(10)
# Out:
#                                                                ru_name  ... answer
# 760498              Общество с ограниченной ответственностью "ПРОСТОР"  ...   True
# 1095640                     Закрытое акционерное общество "Экопрофиль"  ...  False
# 1813241                                                    ООО "Лидер"  ...  False
# 2365385                                              ООО "ДЖМИНА ПЛЭЙ"  ...   True
# 1629797  Общество с ограниченной ответственностью "Партнер-технология"  ...   True
# 2531811          Общество с ограниченной ответственностью "Финагролес"  ...   True
# 667180               Общество с ограниченной ответственностью "ТриМед"  ...   True
# 1381680                                             ООО "ИНЖЕНЕР-УРАЛ"  ...   True
# 2910821            Общество с ограниченной ответственностью "Сапротек"  ...   True
# 1783946                                                      ООО "КСБ"  ...   True
#
# [10 rows x 3 columns]

# %%
valid_data[pred_y.reshape(-1) != val_y.reshape(-1)]['answer'].value_counts()
# Out:
# True     4143
# False    1366
# Name: answer, dtype: int64

# %% [markdown]
# ## Generate predictions for test

# %%
model = keras.models.load_model(glob('best_model/model_*.h5')[0])

# %%
test_X = np.load('processed_data/test/X_processed_0.npy')

# %%
y_pred_test = (model.predict(test_X) > 0.5).reshape(-1)
y_pred_test = pd.Series(y_pred_test)
y_pred_test.name = 'answer'

y_pred_test.to_csv('result.tsv', index=False)

# %%
y_pred_test.mean()
# Out:
# 0.042335139129282405
